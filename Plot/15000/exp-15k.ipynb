# %%
import pickle

import matplotlib.pyplot as plt

from tsml_eval.evaluation import evaluate_classifiers_by_problem

classifiers = [
    "Wasserstein",
    "Moods Median",
    "Kruskal Wallis",
    "F-Stat",
    "Info Gain",
    "Kolmogorov",
    "Info Gain(no_early_abandon)",
]


datasets = [
    "ACSF1",
    "Adiac",
    "ArrowHead",
    "Beef",
    "BeetleFly",
    "BirdChicken",
    "BME",
    "Car",
    "CBF",
    "ToeSegmentation1",
    "ToeSegmentation2",
    "Trace",
    "TwoLeadECG",
    "UWaveGestureLibraryZ",
    "Wafer",
    "Wine",
    "WordSynonyms",
    "Worms",
    "WormsTwoClass",
    "Yoga",
]


evaluate_classifiers_by_problem(
    "../../Runtime Data/15000",
    classifiers,
    datasets,
    "./generated_results/",
    resamples=2,
    eval_name="ExampleEval",
)
# Out:
# /Users/abhashshrestha/anaconda3/lib/python3.11/site-packages/aeon/base/__init__.py:24: FutureWarning: The aeon package will soon be releasing v1.0.0 with the removal of legacy modules and interfaces such as BaseTransformer and BaseForecaster. This will contain breaking changes. See aeon-toolkit.org for more information. Set aeon.AEON_DEPRECATION_WARNING or the AEON_DEPRECATION_WARNING environmental variable to 'False' to disable this warning.
#   warnings.warn(
# All results present, continuing evaluation.
#
# Estimators (7): ['F-Stat', 'Info Gain', 'Info Gain(no_early_abandon)', 'Kolmogorov', 'Kruskal Wallis', 'Moods Median', 'Wasserstein']
#
# Datasets (20): ['ACSF1', 'Adiac', 'ArrowHead', 'BME', 'Beef', 'BeetleFly', 'BirdChicken', 'CBF', 'Car', 'ToeSegmentation1', 'ToeSegmentation2', 'Trace', 'TwoLeadECG', 'UWaveGestureLibraryZ', 'Wafer', 'Wine', 'WordSynonyms', 'Worms', 'WormsTwoClass', 'Yoga']
#
# Resamples (2): [0, 1]
# ...

# %%
with open("./generated_results/ExampleEval/ExampleEval_summary.csv", "rb") as f:
    for _ in range(3):
        print(f.readline().decode("utf-8").strip())
# Out:
# testAccuracy,Kolmogorov,Info Gain,Info Gain(no_early_abandon),Kruskal Wallis,F-Stat,Moods Median,Wasserstein
# testAccuracyMean,0.864126654246882,0.8616845731649649,0.8616845731649649,0.8583650558368632,0.8512924583231201,0.8530209979668925,0.8273346717942184
# testAccuracyAvgRank,3.125,3.45,3.45,3.95,3.975,4.2,5.85

# %%
with open(
    "./generated_results/ExampleEval/Accuracy/figures/"
    "ExampleEval_accuracy_critical_difference.pickle",
    "rb",
) as f:
    fig = pickle.load(f)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd


data = {
    "Quality Measure": [
        "F-Statistics",
        "Information Gain (No Early Abandon)",
        "Information Gain",
        "Kruskal Wallis",
        "Moods Median",
        "Kolmogarov",
        "Wasserstein(Gauss)",
    ],
    "Average RunTime(10000 shapelets)": [
        184.4401,
        240.1128,
        234.4996,
        260.3735,
        191.173125,
        178.6715,
        177.203,
    ],
    "Average Runtime (5000 shapelets)": [
        139.0297,
        163.1185,
        138.6215,
        176.1918,
        145.9394,
        138.3622,
        128.8438,
    ],
    "Average Runtime (15000 shapelets)": [
        223.38185,
        298.1968,
        301.793,
        335.29805,
        233.486925,
        227.1991,
        204.8775,
    ],
    "Average Runtime (2000 shapelets)": [
        110.822,
        117.8062,
        123.0809,
        128.0002,
        114.5772,
        110.6519,
        106.062,
    ],
    "Average Runtime (8000 shapelets)": [
        165.0788,
        211.8056,
        205.636,
        225.835,
        171.7698,
        160.4536,
        150.4779,
    ],
    "Average Runtime (20000 shapelets)": [
        258.9128,
        357.5215,
        355.6074,
        397.2542,
        268.4801,
        252.7311,
        242.2760,
    ],
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Plotting
fig, ax = plt.subplots(1, 3, figsize=(18, 6))

# Plot for 10,000 shapelets
ax[0].barh(
    df["Quality Measure"], df["Average RunTime(10000 shapelets)"], color="skyblue"
)
ax[0].set_title("Average Runtime (10000 shapelets)")
ax[0].set_xlabel("Runtime")

# Plot for 5000 shapelets
ax[1].barh(
    df["Quality Measure"], df["Average Runtime (5000 shapelets)"], color="lightgreen"
)
ax[1].set_title("Average Runtime (5000 shapelets)")
ax[1].set_xlabel("Runtime")

# Plot for 15000 shapelets
ax[2].barh(
    df["Quality Measure"], df["Average Runtime (15000 shapelets)"], color="salmon"
)
ax[2].set_title("Average Runtime (15000 shapelets)")
ax[2].set_xlabel("Runtime")

# ax[3].barh(df["Quality Measure"], df["Average Runtime (2000 shapelets)"], color='red')
# ax[3].set_title('Average Runtime (2000 shapelets)')
# ax[3].set_xlabel('Runtime')

# ax[4].barh(df["Quality Measure"], df["Average Runtime (8000 shapelets)"], color='yellow')
# ax[4].set_title('Average Runtime (8000 shapelets)')
# ax[4].set_xlabel('Runtime')

# ax[5].barh(df["Quality Measure"], df["Average Runtime (20000 shapelets)"], color='black')
# ax[5].set_title('Average Runtime (20000 shapelets)')
# ax[5].set_xlabel('Runtime')

plt.tight_layout()
plt.show()

# %%
df = pd.DataFrame(data)

# Plotting
fig, ax = plt.subplots(1, 3, figsize=(18, 6))

ax[0].barh(df["Quality Measure"], df["Average Runtime (2000 shapelets)"], color="red")
ax[0].set_title("Average Runtime (2000 shapelets)")
ax[0].set_xlabel("Runtime")

ax[1].barh(
    df["Quality Measure"], df["Average Runtime (8000 shapelets)"], color="lightblue"
)
ax[1].set_title("Average Runtime (8000 shapelets)")
ax[1].set_xlabel("Runtime")

ax[2].barh(
    df["Quality Measure"], df["Average Runtime (20000 shapelets)"], color="black"
)
ax[2].set_title("Average Runtime (20000 shapelets)")
ax[2].set_xlabel("Runtime")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Data from the table
data = {
    "Quality Measure": [
        "Kruskal Wallis",
        "Information Gain (No Early Abandon)",
        "Information Gain",
        "F-Statistics",
        "Moods Median",
        "Kolmogarov",
        "Wasserstein(Gauss)",
    ],
    "Average RunTime(10000 shapelets)": [
        260.3735,
        240.1128,
        234.4996,
        184.4401,
        191.173125,
        178.6715,
        177.203,
    ],
    "Average Runtime (5000 shapelets)": [
        176.1918,
        163.1185,
        138.6215,
        139.0297,
        145.9394,
        138.3622,
        128.8438,
    ],
    "Average Runtime (15000 shapelets)": [
        335.29805,
        298.1968,
        301.793,
        223.38185,
        233.486925,
        227.1991,
        204.8775,
    ],
    "Average Runtime (2000 shapelets)": [
        128.0002,
        117.8062,
        123.0809,
        110.822,
        114.5772,
        110.6519,
        106.062,
    ],
    "Average Runtime (8000 shapelets)": [
        225.835,
        211.8056,
        205.636,
        165.0788,
        171.7698,
        160.4536,
        150.4779,
    ],
    "Average Runtime (20000 shapelets)": [
        397.2542,
        357.5215,
        355.6074,
        258.9128,
        268.4801,
        252.7311,
        242.2760,
    ],
}

# %%
# Plotting the graph with lines instead of bars
plt.figure(figsize=(10, 6))

# Plotting lines for each shapelet scenario
plt.plot(
    df["Quality Measure"],
    df["Average Runtime (15000 shapelets)"],
    marker="o",
    label="15000 shapelets",
    linestyle="-",
    color="salmon",
)
plt.plot(
    df["Quality Measure"],
    df["Average RunTime(10000 shapelets)"],
    marker="o",
    label="10000 shapelets",
    linestyle="-",
    color="blue",
)
plt.plot(
    df["Quality Measure"],
    df["Average Runtime (5000 shapelets)"],
    marker="o",
    label="5000 shapelets",
    linestyle="-",
    color="green",
)

plt.plot(
    df["Quality Measure"],
    df["Average Runtime (2000 shapelets)"],
    marker="o",
    label="2000 shapelets",
    linestyle="-",
    color="red",
)
plt.plot(
    df["Quality Measure"],
    df["Average Runtime (8000 shapelets)"],
    marker="o",
    label="8000 shapelets",
    linestyle="-",
    color="yellow",
)
plt.plot(
    df["Quality Measure"],
    df["Average Runtime (20000 shapelets)"],
    marker="o",
    label="20000 shapelets",
    linestyle="-",
    color="black",
)


# Adding titles and labels
plt.title("Average Runtime Comparison for Different Shapelets")
plt.xlabel("Quality Measure")
plt.ylabel("Runtime")
plt.xticks(rotation=45, ha="right")
plt.legend()

plt.tight_layout()
plt.show()
